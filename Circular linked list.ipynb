# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder

# %%
df=pd.read_csv(r"C:\Users\nikhi\Downloads\student_performance_dataset.csv")
df
# Out:
#     Student_ID  Gender  Study_Hours_per_Week  Attendance_Rate  \
# 0         S147    Male                    31        68.267841
# 1         S136    Male                    16        78.222927
# 2         S209  Female                    21        87.525096
# 3         S458  Female                    27        92.076483
# 4         S078  Female                    37        98.655517
# ..         ...     ...                   ...              ...
# 703       S492    Male                    14        84.658761
# 704       S301    Male                    35        60.278990
# 705       S473    Male                    25        98.384969
# 706       S307  Female                    21        96.148012
# 707       S046  Female                    22        80.404392
#
#      Past_Exam_Scores Parental_Education_Level Internet_Access_at_Home  \
# 0                  86              High School                     Yes
# 1                  73                      PhD                      No
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                    0
# Gender                        0
# Study_Hours_per_Week          0
# Attendance_Rate               0
# Past_Exam_Scores              0
# Parental_Education_Level      0
# Internet_Access_at_Home       0
# Extracurricular_Activities    0
# Final_Exam_Score              0
# Pass_Fail                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  708 non-null    object
#  1   Gender                      708 non-null    object
#  2   Study_Hours_per_Week        708 non-null    int64
#  3   Attendance_Rate             708 non-null    float64
#  4   Past_Exam_Scores            708 non-null    int64
#  5   Parental_Education_Level    708 non-null    object
#  6   Internet_Access_at_Home     708 non-null    object
#  7   Extracurricular_Activities  708 non-null    object
#  8   Final_Exam_Score            708 non-null    int64
#  9   Pass_Fail                   708 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 55.4+ KB

# %%
df.describe()
# Out:
#        Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# count            708.000000       708.000000        708.000000
# mean              26.132768        78.107722         77.871469
# std                8.877727        13.802802         14.402739
# min               10.000000        50.116970         50.000000
# 25%               19.000000        67.550094         65.000000
# 50%               27.000000        79.363046         79.000000
# 75%               34.000000        89.504232         91.000000
# max               39.000000        99.967675        100.000000
#
#        Final_Exam_Score
# count        708.000000
# mean          58.771186
# std            6.705877
# min           50.000000
# 25%           52.000000
# 50%           59.500000
# 75%           64.000000
# max           77.000000

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 703    False
# 704     True
# 705    False
# 706     True
# 707    False
# Length: 708, dtype: bool

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#     Student_ID Gender  Study_Hours_per_Week  Attendance_Rate  \
# 0         S147      M                    31        68.267841
# 1         S136      M                    16        78.222927
# 2         S209      F                    21        87.525096
# 3         S458      F                    27        92.076483
# 4         S078      F                    37        98.655517
# ..         ...    ...                   ...              ...
# 701       S118      F                    21        69.858192
# 702       S358      F                    22        93.349688
# 703       S492      M                    14        84.658761
# 705       S473      M                    25        98.384969
# 707       S046      F                    22        80.404392
#
#      Past_Exam_Scores Parental_Education_Level Internet_Access_at_Home  \
# 0                  86              High School                     Yes
# 1                  73                      PhD                      No
# ...

# %%
df['Gender'] = df['Gender'].replace({'Male': 'M', 'Female': 'F'})
df
# Out:
#     Student_ID Gender  Study_Hours_per_Week  Attendance_Rate  \
# 0         S147      M                    31        68.267841
# 1         S136      M                    16        78.222927
# 2         S209      F                    21        87.525096
# 3         S458      F                    27        92.076483
# 4         S078      F                    37        98.655517
# ..         ...    ...                   ...              ...
# 703       S492      M                    14        84.658761
# 704       S301      M                    35        60.278990
# 705       S473      M                    25        98.384969
# 706       S307      F                    21        96.148012
# 707       S046      F                    22        80.404392
#
#      Past_Exam_Scores Parental_Education_Level Internet_Access_at_Home  \
# 0                  86              High School                     Yes
# 1                  73                      PhD                      No
# ...

# %%
Scaler=MinMaxScaler()
df[['Study_Hours_per_Week', 'Attendance_Rate', 'Past_Exam_Scores', 'Final_Exam_Score']] = scaler.fit_transform(df[['Study_Hours_per_Week', 'Attendance_Rate', 'Past_Exam_Scores', 'Final_Exam_Score']])
df
# Out:
#     Student_ID Gender  Study_Hours_per_Week  Attendance_Rate  \
# 0         S147      M              0.724138         0.364105
# 1         S136      M              0.206897         0.563803
# 2         S209      F              0.379310         0.750403
# 3         S458      F              0.586207         0.841704
# 4         S078      F              0.931034         0.973678
# ..         ...    ...                   ...              ...
# 701       S118      F              0.379310         0.396007
# 702       S358      F              0.413793         0.867244
# 703       S492      M              0.137931         0.692905
# 705       S473      M              0.517241         0.968251
# 707       S046      F              0.413793         0.607563
#
#      Past_Exam_Scores Parental_Education_Level Internet_Access_at_Home  \
# 0                0.72              High School                     Yes
# 1                0.46                      PhD                      No
# ...

# %%
Scaler_std=StandardScaler()
df[['Study_Hours_per_Week', 'Attendance_Rate', 'Past_Exam_Scores', 'Final_Exam_Score']] = Scaler_std.fit_transform(df[['Study_Hours_per_Week', 'Attendance_Rate', 'Past_Exam_Scores', 'Final_Exam_Score']])
df
# Out:
#     Student_ID Gender  Study_Hours_per_Week  Attendance_Rate  \
# 0         S147      M              0.661242        -0.541937
# 1         S136      M             -1.044161         0.171423
# 2         S209      F             -0.475694         0.837996
# 3         S458      F              0.206467         1.164138
# 4         S078      F              1.343403         1.635578
# ..         ...    ...                   ...              ...
# 701       S118      F             -0.475694        -0.427976
# 702       S358      F             -0.362000         1.255373
# 703       S492      M             -1.271548         0.632600
# 705       S473      M             -0.020920         1.616191
# 707       S046      F             -0.362000         0.327742
#
#      Past_Exam_Scores Parental_Education_Level Internet_Access_at_Home  \
# 0            0.747277              High School                     Yes
# 1           -0.153725                      PhD                      No
# ...

# %%
encoder = LabelEncoder()
cat=['Gender', 'Parental_Education_Level', 'Internet_Access_at_Home','Extracurricular_Activities', 'Pass_Fail']
for col in cat:
    df[col] = LabelEncoder().fit_transform(df[col])
df
# Out:
#     Student_ID  Gender  Study_Hours_per_Week  Attendance_Rate  \
# 0         S147       1                    31        68.267841
# 1         S136       1                    16        78.222927
# 2         S209       0                    21        87.525096
# 3         S458       0                    27        92.076483
# 4         S078       0                    37        98.655517
# ..         ...     ...                   ...              ...
# 703       S492       1                    14        84.658761
# 704       S301       1                    35        60.278990
# 705       S473       1                    25        98.384969
# 706       S307       0                    21        96.148012
# 707       S046       0                    22        80.404392
#
#      Past_Exam_Scores  Parental_Education_Level  Internet_Access_at_Home  \
# 0                  86                         1                        1
# ...

# %%
logtrans=['Study_Hours_per_Week', 'Attendance_Rate', 'Past_Exam_Scores', 'Final_Exam_Score']
for coll in logtrans:
    df[coll]=np.log10(df[coll])
df
# Out:
#     Student_ID  Gender  Study_Hours_per_Week  Attendance_Rate  \
# 0         S147       1              0.539795         0.627159
# 1         S136       1              0.452279         0.640707
# 2         S209       0              0.490105         0.651596
# 3         S458       0              0.522732         0.656426
# 4         S078       0              0.560813         0.662920
# ..         ...     ...                   ...              ...
# 703       S492       1              0.432657         0.648396
# 704       S301       1              0.554310         0.614416
# 705       S473       1              0.512964         0.662663
# 706       S307       0              0.490105         0.660508
# 707       S046       0              0.496306         0.643396
#
#      Past_Exam_Scores  Parental_Education_Level  Internet_Access_at_Home  \
# 0            0.649910                         1                        1
# ...
